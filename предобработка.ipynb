# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

# %%
df = pd.read_csv(r'C:\\Users\\VikA\\Desktop\\программы\\Книга1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10696 entries, 0 to 10695
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   author                  10605 non-null  object
#  1   author_type             10605 non-null  object
#  2   url                     10684 non-null  object
#  3   location                10278 non-null  object
#  4   deal_type               10686 non-null  object
#  5   accommodation_type      10684 non-null  object
#  6   floor                   10682 non-null  float64
#  7   floors_count            10682 non-null  float64
#  8   rooms_count             10682 non-null  float64
#  9   total_meters            10682 non-null  object
#  10  price                   10662 non-null  float64
#  11  year_of_construction    10682 non-null  object
#  12  object_type             10682 non-null  object
#  13  house_material_type     10682 non-null  object
# ...

# %%
cols = df.columns[:30] # первые 30 колонок
# определяем цвета 
# желтый - пропущенные данные, фиолетовый- не пропущенные
colours = ['#800080', '#ffff00'] 
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# author - 1%
# author_type - 1%
# url - 0%
# location - 4%
# deal_type - 0%
# accommodation_type - 0%
# floor - 0%
# floors_count - 0%
# rooms_count - 0%
# total_meters - 0%
# price - 0%
# year_of_construction - 0%
# object_type - 0%
# house_material_type - 0%
# heating_type - 0%
# finish_type - 0%
# living_meters - 0%
# kitchen_meters - 0%
# phone - 0%
# district - 34%
# street - 14%
# house_number - 13%
# underground - 41%
# residential_complex - 52%
# author.1 - 1%
# author_type.1 - 1%
# url.1 - 0%
# location.1 - 4%
# deal_type.1 - 0%
# accommodation_type.1 - 0%
# floor.1 - 0%
# floors_count.1 - 0%
# rooms_count.1 - 0%
# total_meters.1 - 0%
# price.1 - 0%
# year_of_construction.1 - 0%
# object_type.1 - 0%
# house_material_type.1 - 0%
# heating_type.1 - 0%
# finish_type.1 - 0%
# living_meters.1 - 0%
# kitchen_meters.1 - 0%
# phone.1 - 0%
# district.1 - 34%
# street.1 - 14%
# house_number.1 - 13%
# underground.1 - 41%
# residential_complex.1 - 52%

# %%
df = df.drop(['phone', 'street','residential_complex','author.1'	,'author_type.1'	,'url.1',	'location.1',	'deal_type.1',	'accommodation_type.1','floor.1',	'floors_count.1',	'rooms_count.1',	'total_meters.1',	'price.1',	'year_of_construction.1',	'object_type.1',	'house_material_type.1',	'heating_type.1',	'finish_type.1','living_meters.1',	'kitchen_meters.1','phone.1',	'district.1',	'street.1',	'house_number.1',	'underground.1',	'residential_complex.1',	
], axis=1)  #УДАЛИЛА НЕ НУЖНЫЕ СТОЛБЦЫ

# %%
df.head()
# Out:
#                             author        author_type  \
# 0  Р“Р°Р»СЃ-Р”РµРІРµР»РѕРїРјРµРЅС‚          developer
# 1          Point Estate Р“РѕСЂРѕРґ  real_estate_agent
# 2           РС‚Р°Р¶Рё РњРѕСЃРєРІР°  real_estate_agent
# 3                           Sminex          developer
# 4                        Whitewill  real_estate_agent
#
#                                         url      location deal_type  \
# 0  https://www.cian.ru/sale/flat/308080996/  РњРѕСЃРєРІР°      sale
# 1  https://www.cian.ru/sale/flat/307575540/  РњРѕСЃРєРІР°      sale
# 2  https://www.cian.ru/sale/flat/298845467/  РњРѕСЃРєРІР°      sale
# 3  https://www.cian.ru/sale/flat/293713880/  РњРѕСЃРєРІР°      sale
# 4  https://www.cian.ru/sale/flat/302177521/  РњРѕСЃРєРІР°      sale
#
#   accommodation_type  floor  floors_count  rooms_count total_meters  ...  \
# 0               flat    2.0           6.0          2.0        71.56  ...
# 1               flat    4.0          21.0          2.0         54.0  ...
# ...

# %%
cols = df.columns[:30] # первые 30 колонок
# определяем цвета 
# желтый - пропущенные данные, фиолетовый - не пропущенные
colours = ['#800080', '#ffff00'] 
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
df_unique_subset = df.drop_duplicates() #удаление дубликатов

print(df_unique_subset)
# Out:
#                                 author        author_type  \
# 0      Р“Р°Р»СЃ-Р”РµРІРµР»РѕРїРјРµРЅС‚          developer
# 1              Point Estate Р“РѕСЂРѕРґ  real_estate_agent
# 2               РС‚Р°Р¶Рё РњРѕСЃРєРІР°  real_estate_agent
# 3                               Sminex          developer
# 4                            Whitewill  real_estate_agent
# ...                                ...                ...
# 10691               Наталья Бондаренко            realtor
# 10692                    Евгений Цопин            realtor
# 10693                      OPN PARTNER  real_estate_agent
# 10694                      OPN PARTNER  real_estate_agent
# 10695                       ПЯТЬ ЗВЕЗД  real_estate_agent
#
#                                                 url      location deal_type  \
# 0          https://www.cian.ru/sale/flat/308080996/  РњРѕСЃРєРІР°      sale
# 1          https://www.cian.ru/sale/flat/307575540/  РњРѕСЃРєРІР°      sale
# ...

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# author - 1%
# author_type - 1%
# url - 0%
# location - 4%
# deal_type - 0%
# accommodation_type - 0%
# floor - 0%
# floors_count - 0%
# rooms_count - 0%
# total_meters - 0%
# price - 0%
# year_of_construction - 0%
# object_type - 0%
# house_material_type - 0%
# heating_type - 0%
# finish_type - 0%
# living_meters - 0%
# kitchen_meters - 0%
# district - 34%
# house_number - 13%
# underground - 41%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10696 entries, 0 to 10695
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                10605 non-null  object
#  1   author_type           10605 non-null  object
#  2   url                   10684 non-null  object
#  3   location              10278 non-null  object
#  4   deal_type             10686 non-null  object
#  5   accommodation_type    10684 non-null  object
#  6   floor                 10682 non-null  float64
#  7   floors_count          10682 non-null  float64
#  8   rooms_count           10682 non-null  float64
#  9   total_meters          10682 non-null  object
#  10  price                 10662 non-null  float64
#  11  year_of_construction  10682 non-null  object
#  12  object_type           10682 non-null  object
#  13  house_material_type   10682 non-null  object
# ...

# %%
sns.heatmap(df[['floor','floors_count','price','rooms_count']].corr(), annot=True)
plt.show()

# %%
df.to_csv('готовые_данные')
